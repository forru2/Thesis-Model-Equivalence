# %%
from Utils import concatenate_df
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from rashomon import get_rashomon, rashomon_ratio
import os
from sklearn.preprocessing import MinMaxScaler, RobustScaler
import plots
from sklearn.cluster import OPTICS
import pacmap

# %%
full_df = concatenate_df(path = r'C:\Users\franc\OneDrive\Magistrale\Thesis-Model-Equivalence\Results\german\rtc',
                      file_names = '*_holdout')

cols_to_keep = [col for col in full_df.columns if col.startswith('val_') or col in ['n_neighbors', 'model_id']]
df = full_df[cols_to_keep]

# %% [markdown]
# baseline_path = r'C:\Users\franc\OneDrive\Magistrale\Thesis-Model-Equivalence\Results\german\baseline\rtc_complexity\8fcc2b79d802f0b90eaf276a928a62ed_holdout.csv'
# baseline_df_full = pd.read_csv(baseline_path)
# bsl_cols = [col for col in baseline_df_full.columns if col.startswith('val_')]
# baseline_df = baseline_df_full[bsl_cols]

# %% [markdown]
# baseline_df.columns

# %%
scaler = RobustScaler().set_output()
scaled_data = scaler.fit_transform(df.select_dtypes('number'))

# %%
embedding = pacmap.PaCMAP(n_components=2, n_neighbors=10, MN_ratio=3.0, FP_ratio=0.5, random_state = 0) 
cmap_data = embedding.fit_transform(scaled_data, init = 'pca')
# Out:
# Warning: random state is set to 0.

# %% [markdown]
# ## Sparsity of the models

# %%
figure = plt.figure(figsize = (8, 6))
hb = plt.hexbin(cmap_data[:, 0], cmap_data[:, 1], gridsize=40, bins = 'log', cmap='viridis_r')
cb = figure.colorbar(hb)
cb.set_label('n. models')

plt.title('Model Distribution (LR)')

file_dir = r'C:\Users\franc\OneDrive\Magistrale\Thesis-Model-Equivalence\Results\german\plots'
title = 'Model Distribution (LR)'
#plt.savefig(os.path.join(file_dir, f'{title}.png'), dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.hist(df['val_accuracy'], bins = 30, color='skyblue', edgecolor='white', alpha=0.8)
ax1.axvline(df['val_accuracy'].mean(), color='red', linestyle='dashed', linewidth=1.5, label='mean')
ax1.axvline(df['val_accuracy'].median(), color='green', linestyle='dashed', linewidth=1.5, label='median')
ax1.set_title("Accuracy Distribution")
ax1.legend()

ax2.hist(df['val_f1'], bins=30, color='skyblue', edgecolor='white', alpha=0.8)
ax2.axvline(df['val_f1'].mean(), color='red', linestyle='dashed', linewidth=1.5, label='mean')
ax2.axvline(df['val_f1'].median(), color='green', linestyle='dashed', linewidth=1.5, label='median')
ax2.set_title("F1 Distribution")
ax2.legend()

file_dir = r'C:\Users\franc\OneDrive\Magistrale\Thesis-Model-Equivalence\Results\german\plots'
title = 'Performance distribution (LR)'
#plt.savefig(os.path.join(file_dir, f'{title}.png'), dpi = 300, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## Rashomon Set definition

# %%
threshold = np.linspace(0, 1, 50)
def rr_variation(df, threshold, tol, metric):
    ratios = []
    for t in threshold:
        cond = f'{metric} >= {t} + {tol}'
        ratio = rashomon_ratio(df, cond)        
        ratios.append(ratio)
    return ratios

ratios1 = rr_variation(df, threshold, tol = 0, metric = 'val_f1')
ratios2 = rr_variation(df, threshold, tol = - 0.1, metric = 'val_f1')
ratios3 = rr_variation(df, threshold, tol = - 0.2, metric = 'val_f1')

# %%
plt.figure(figsize = (6,4))
plt.plot(threshold, ratios1, color='g', label = 'eps = 0')
plt.plot(threshold, ratios2, color='b', label = 'eps = - 0.1')
plt.plot(threshold, ratios3, color='r', label = 'eps = - 0.2')
plt.title('Rashomon Ratio Variation wrt F1 Threshold')
plt.legend()
plt.xlabel('f1_threshold')
plt.ylabel('Rashomon Ratio')

file_dir = r'C:\Users\franc\OneDrive\Magistrale\Thesis-Model-Equivalence\Results\german\plots'
title = 'rr variation f1(RTC)'
#plt.savefig(os.path.join(file_dir, f'{title}.png'), dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
 df['val_f1'].max()
# Out:
# 0.5918367346938775

# %%
metric = np.sort(df['val_f1'].values)
epsilon = 0.15
soglia = df['val_f1'].max() - epsilon
cond = f'val_f1 >= {soglia}'
rr = rashomon_ratio(df, cond)
plt.figure(figsize = (6,4))
plt.plot(metric, color='g')
plt.axhline(y = soglia, color='black', linestyle='--', label=f'soglia = baseline - {epsilon}')
plt.axvline(x = (1-rr)*1000, color='red', linestyle='--', label=f'rr = {rr}')
plt.title('Rashomon Set per F1 Score')
plt.legend()
plt.xlabel('Spazio di Ipotesi')
plt.ylabel('F1 Score')

file_dir = r'C:\Users\franc\OneDrive\Magistrale\Thesis-Model-Equivalence\Results\german\plots'
title = 'rash f1(RTC)'
#plt.savefig(os.path.join(file_dir, f'{title}.png'), dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
_, rash_df = get_rashomon(df, cond)

# %%
rash_df.columns
# Out:
# Index(['model_id', 'val_accuracy', 'val_f1', 'val_precision', 'val_recall',
#        'val_equalized_odds', 'val_cuae', 'val_dem_parity',
#        'val_equal_opportunity', 'val_predictive_equality',
#        'val_predictive_parity', 'val_neg_predictive_parity',
#        'val_acc_robustness', 'val_f1_robustness', 'val_precision_robustness',
#        'val_recall_robustness', 'val_dem_parity_robustness',
#        'val_equal_opp_robustness', 'val_predictive_eq_robustness',
#        'val_pred_parity_robustness', 'val_neg_pred_parity_robustness',
#        'val_eq_odds_robustness', 'val_rtc_depth', 'val_rtc_n_nodes',
#        'val_rtc_n_rules'],
#       dtype='object')

# %%
for col in df.columns:
    if col != 'model_id':
        print(f'{col}: {round(df[col].mean(), 3)}')
# Out:
# val_accuracy: 0.684
# val_f1: 0.421
# val_precision: 0.47
# val_recall: 0.398
# val_equalized_odds: 0.463
# val_cuae: 0.736
# val_dem_parity: 0.2
# val_equal_opportunity: 0.444
# val_predictive_equality: 0.204
# val_predictive_parity: 0.733
# val_neg_predictive_parity: 0.269
# val_acc_robustness: 0.97
# val_f1_robustness: 0.921
# val_precision_robustness: 0.928
# val_recall_robustness: 0.903
# val_dem_parity_robustness: 0.872
# val_equal_opp_robustness: 0.854
# val_predictive_eq_robustness: 0.82
# val_pred_parity_robustness: 0.829
# val_neg_pred_parity_robustness: 0.847
# val_eq_odds_robustness: 0.872
# val_rtc_depth: 8.671
# val_rtc_n_nodes: 76.17
# val_rtc_n_rules: 38.585

# %% [markdown]
# ## Correlation on metrics

# %%
corr_df = df.select_dtypes(include=['number'])

# %%
corr_matrix = corr_df.corr()
plots.plot_corr_matrix(corr_matrix, annot = True, title = 'Correlation Matrix for Rashomon set selection metrics', save_plot = False,
                   file_dir = r'C:\Users\franc\OneDrive\Magistrale\Thesis-Model-Equivalence\Results\plots')

# %% [markdown]
# ## Correlation btw models in/not in the rashomon set

# %%
not_rash_df = df[~ df['model_id'].isin(rash_df['model_id'])]

# %%
rash_corr_matrix = rash_df.select_dtypes(include=['number']).corr()
not_rash_corr_matrix = not_rash_df.select_dtypes(include=['number']).corr()

# %%
plots.plot_corr_matrix_grid([rash_corr_matrix, not_rash_corr_matrix],
                            ['Rashomon correlation matrix', 'Non-Rashomon correlation matrix'],
                            cols = 2,
                            annot = True,
                            figsize_unit = (12, 11)
                           )

# %%
df
# Out:
#                               model_id  \
# 0     3d3fbc9a0553c6433eb21980c33cef08
# 1     0007f208a9ab574493a22ebdb26fedc7
# 2     003ce8c1d478af4bfebe9ae54f4328a1
# 3     00880a40ef0c9d858bcfaaafc640ac04
# 4     00c82bb517ca675a88a1b651d1a0607f
# ...                                ...
# 2996  fe9487e8563fd82eb2192806c299015e
# 2997  fed8b3588d6395ae7fc0dec4aeb7cac6
# 2998  feda33151f51715f6308915bd5e043f4
# 2999  fee349f0d2ea83cec17de24541bb0c2d
# 3000  ffa72e2535b919087b93cad969ba01c8
#
#                                                  params  val_accuracy  \
# 0     {"criterion": "gini", "max_depth": 20, "min_sa...      0.735714
# 1     {"n_neighbors": 8, "p": 1.6531, "weights": "un...      0.697143
# 2     {"n_neighbors": 5, "p": 1.5714, "weights": "un...      0.695714
# 3     {"n_neighbors": 7, "p": 1.0, "weights": "unifo...      0.705714
# 4     {"n_neighbors": 5, "p": 3.6122, "weights": "di...      0.665714
# ...                                                 ...           ...
# 2996  {"criterion": "gini", "max_depth": 13, "min_sa...      0.715714
# 2997  {"criterion": "gini", "max_depth": 11, "min_sa...      0.722857
# 2998  {"criterion": "gini", "max_depth": 13, "min_sa...      0.707143
# 2999  {"criterion": "entropy", "max_depth": 13, "min...      0.707143
# 3000  {"criterion": "entropy", "max_depth": 9, "min_...      0.720000
#
#         val_f1  val_precision  val_recall  val_equalized_odds  val_cuae  \
# 0     0.432733       0.606026    0.338095            0.383117  0.651465
# 1     0.205443       0.495629    0.133333            0.254762  0.713333
# 2     0.363110       0.494529    0.300000            0.450952  0.703333
# 3     0.368541       0.520438    0.295238            0.396429  0.654286
# 4     0.317155       0.425238    0.257143            0.394545  0.616667
# ...        ...            ...         ...                 ...       ...
# 2996  0.484584       0.538345    0.457143            0.433247  0.583889
# 2997  0.464168       0.559498    0.404762            0.577273  0.650693
# 2998  0.408842       0.515616    0.342857            0.446499  0.724596
# 2999  0.408842       0.515616    0.342857            0.446499  0.724596
# 3000  0.501078       0.538797    0.471429            0.534892  0.675844
#
#       val_dem_parity  val_equal_opportunity  ...  val_acc_robustness  \
# 0           0.196777               0.383117  ...            0.975945
# 1           0.149320               0.254762  ...            0.975882
# 2           0.232333               0.443810  ...            0.965806
# 3           0.267994               0.396429  ...            0.971265
# 4           0.166055               0.343810  ...            0.961314
# ...              ...                    ...  ...                 ...
# 2996        0.227230               0.421429  ...            0.962322
# 2997        0.266424               0.577273  ...            0.968761
# 2998        0.238749               0.446499  ...            0.959038
# 2999        0.238749               0.446499  ...            0.960547
# 3000        0.287916               0.534892  ...            0.972724
#
#       val_f1_robustness  val_precision_robustness  val_recall_robustness  \
# 0              0.931484                  0.932414               0.929083
# 1              0.943201                  0.866453               0.959559
# 2              0.931962                  0.916183               0.933548
# 3              0.932226                  0.910566               0.941550
# 4              0.929512                  0.910874               0.934956
# ...                 ...                       ...                    ...
# 2996           0.926140                  0.919894               0.906016
# 2997           0.935879                  0.933112               0.919919
# 2998           0.913369                  0.919394               0.899912
# 2999           0.924540                  0.923696               0.914447
# 3000           0.940730                  0.941546               0.922933
#
#       val_dem_parity_robustness  val_equal_opp_robustness  \
# 0                      0.907309                  0.847498
# 1                      0.959175                  0.927581
# 2                      0.897549                  0.860094
# 3                      0.950787                  0.909178
# 4                      0.925729                  0.870629
# ...                         ...                       ...
# 2996                   0.898065                  0.835672
# 2997                   0.911215                  0.819659
# 2998                   0.901436                  0.853051
# 2999                   0.880628                  0.860699
# 3000                   0.911917                  0.876136
#
#       val_predictive_eq_robustness  val_pred_parity_robustness  \
# 0                         0.910129                    0.846705
# 1                         0.921556                    0.843011
# 2                         0.892918                    0.835642
# 3                         0.931751                    0.850892
# 4                         0.918275                    0.837906
# ...                            ...                         ...
# 2996                      0.887277                    0.844218
# 2997                      0.889655                    0.837993
# 2998                      0.904078                    0.828415
# 2999                      0.886931                    0.864677
# 3000                      0.886451                    0.848861
#
#       val_neg_pred_parity_robustness  val_eq_odds_robustness
# 0                           0.883148                1.699011
# 1                           0.889382                1.764795
# 2                           0.870300                1.691409
# 3                           0.883424                1.750346
# 4                           0.875981                1.713111
# ...                              ...                     ...
# 2996                        0.842488                1.680570
# 2997                        0.858308                1.659888
# 2998                        0.837840                1.684945
# 2999                        0.840013                1.698321
# 3000                        0.866718                1.717161
#
# [3001 rows x 23 columns]

# %%
#val_recall
plots.plot_corr_scatter(rash_df, not_rash_df, x = 'val_f1', y = 'val_dem_parity',
                        titles = ['f1 / dem_parity correlation (overview)', 'f1 / dem_parity correlation in Rashomon'],
                       figsize = (12, 5))

# %% [markdown]
# ## Clustering of Rashomon set

# %% [markdown]
# x = 'val_f1'
# y = 'val_dem_parity'
# z = 'val_f1_robustness'
#
# plots.plot_rashomon(df, x, y, z, rash_models)

# %%
scaler = MinMaxScaler().set_output(transform = 'pandas')
scaled_rash_df = scaler.fit_transform(rash_df.select_dtypes(include=['number']))

# %%
scaled_rash_df.columns
# Out:
# Index(['val_accuracy', 'val_f1', 'val_precision', 'val_recall',
#        'val_equalized_odds', 'val_cuae', 'val_dem_parity',
#        'val_equal_opportunity', 'val_predictive_equality',
#        'val_predictive_parity', 'val_neg_predictive_parity',
#        'val_acc_robustness', 'val_f1_robustness', 'val_precision_robustness',
#        'val_recall_robustness', 'val_dem_parity_robustness',
#        'val_equal_opp_robustness', 'val_predictive_eq_robustness',
#        'val_pred_parity_robustness', 'val_neg_pred_parity_robustness',
#        'val_eq_odds_robustness'],
#       dtype='object')

# %%
fairness_df = scaled_rash_df[['val_equalized_odds', 'val_cuae', 'val_predictive_equality', 'val_neg_predictive_parity']].copy()

robustness_df = scaled_rash_df[['val_acc_robustness', 'val_f1_robustness', 'val_precision_robustness',
       'val_recall_robustness', 'val_dem_parity_robustness',
       'val_equal_opp_robustness', 'val_predictive_eq_robustness',
       'val_pred_parity_robustness', 'val_neg_pred_parity_robustness',
       'val_eq_odds_robustness']].copy()

# %%
len(fairness_df)
# Out:
# 611

# %%
clustering = OPTICS(min_samples = 20, xi = 0.01).fit(fairness_df)

n_clusters = len(set(clustering.labels_)) - (1 if -1 in clustering.labels_ else 0)
n_noise = list(clustering.labels_).count(-1)/len(fairness_df)*100
print(f'n_clusters: \n{n_clusters}')
print(f'n_noise: \n{int(n_noise)}%')
# Out:
# n_clusters:
# 8
# n_noise:
# 51%
# C:\Users\franc\anaconda3\envs\py312\Lib\site-packages\sklearn\cluster\_optics.py:1084: RuntimeWarning: divide by zero encountered in divide
#   ratio = reachability_plot[:-1] / reachability_plot[1:]

# %%
plots.plot_reachability_graph(clustering)

# %%
for cluster in np.unique(clustering.labels_):
    print(f'n models in cluster {cluster}: {list(clustering.labels_).count(cluster)}')
# Out:
# n models in cluster -1: 312
# n models in cluster 0: 63
# n models in cluster 1: 46
# n models in cluster 2: 22
# n models in cluster 3: 22
# n models in cluster 4: 35
# n models in cluster 5: 20
# n models in cluster 6: 49
# n models in cluster 7: 42

# %%
rash_df.columns
# Out:
# Index(['model_id', 'params', 'val_accuracy', 'val_f1', 'val_precision',
#        'val_recall', 'val_equalized_odds', 'val_cuae', 'val_dem_parity',
#        'val_equal_opportunity', 'val_predictive_equality',
#        'val_predictive_parity', 'val_neg_predictive_parity',
#        'val_acc_robustness', 'val_f1_robustness', 'val_precision_robustness',
#        'val_recall_robustness', 'val_dem_parity_robustness',
#        'val_equal_opp_robustness', 'val_predictive_eq_robustness',
#        'val_pred_parity_robustness', 'val_neg_pred_parity_robustness',
#        'val_eq_odds_robustness'],
#       dtype='object')

# %%
rash_df_copy = rash_df.copy()
rash_df_copy['cluster'] = clustering.labels_


for cluster in np.unique(clustering.labels_):
    max_fairness = float('-inf')
    max_fairness_cluster = None
    fairness = rash_df_copy[rash_df_copy['cluster'] == cluster]['val_equalized_odds'].mean()
    print(f'avg fairness for cluster {cluster}:', fairness)
    if fairness > max_fairness:
        max_fairness = fairness
        max_fairness_cluster = cluster
print(f'\nmax fairness in cluster {max_fairness_cluster}')
# Out:
# avg fairness for cluster -1: 0.5004331519692773
# avg fairness for cluster 0: 0.43014015427460806
# avg fairness for cluster 1: 0.4439511575381141
# avg fairness for cluster 2: 0.4247871068325612
# avg fairness for cluster 3: 0.45353464717101066
# avg fairness for cluster 4: 0.38619152276295127
# avg fairness for cluster 5: 0.45281818181818184
# avg fairness for cluster 6: 0.55538203687272
# avg fairness for cluster 7: 0.5581047206761491
#
# max fairness in cluster 7

# %%
reduced_df = plots.feature_reduction(fairness_df, clustering, method = PCA)
plots.plot_clustering(reduced_df, clustering)
